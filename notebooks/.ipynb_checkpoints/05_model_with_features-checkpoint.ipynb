# %% [markdown]
#  # Logistic Regression with cleaned text + structured features

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load dataset with cleaned text and structured features
df = pd.read_pickle("acled_cleaned.pkl")
df.head()
# Out:
#    Unnamed: 0 event_id_cnty                  event_type  event_date  \
# 0           0      SOM45530  Explosions/Remote violence  2024-08-25
# 1           1      SOM45523  Violence against civilians  2024-08-24
# 2           2        MUS523                    Protests  2024-08-27
# 3           3     IND165800      Strategic developments  2024-08-27
# 4           4      IRQ58463      Strategic developments  2024-08-27
#
#      country   admin1    admin2                  actor1  \
# 0    Somalia  Banadir   Banadir              Al Shabaab
# 1    Somalia  Banadir   Banadir              Al Shabaab
# 2  Mauritius     Moka       NaN  Protesters (Mauritius)
# 3      India    Assam    Nagaon       Civilians (India)
# 4       Iraq   Ninewa  Al Mosul        Civilians (Iraq)
#
#                                               actor2  \
# 0                 Military Forces of Somalia (2022-)
# 1                                Civilians (Somalia)
# 2  Police Forces of Mauritius (2018-) Special Sup...
# 3                                                NaN
# 4                                                NaN
#
#                                    event_description  fatalities  latitude  \
# 0  On 25 August 2024, an IED planted by Al Shabaa...           2    2.0611
# 1  On 24 August 2024, Al Shabaab shot and killed ...           2    2.0576
# 2  On 27 August 2024, at the call of the Rann Nou...           0  -20.2190
# 3  Other: On 27 August 2024, a section of fish tr...           0   26.3469
# 4  Other: On 27 August 2024, 517 displaced people...           0   36.3350
#
#    longitude  label                                  clean_description  \
# 0    45.2589      1  August ied plant Al Shabaab detonate target go...
# 1    45.2853      5  August Al Shabaab shoot kill government soldie...
# 2    57.5108      2  August Rann Nou La Terre movement Indo Mauriti...
# 3    92.6851      4  August section fish trader announce halt expor...
# 4    43.1189      4  August displace people return Dibaga Camp Erbi...
#
#    fatalities_clipped  desc_length
# 0                   2           26
# 1                   2           25
# 2                   0           66
# 3                   0           35
# 4                   0           29

# %%
# Preprocessing structured features
df['fatalities'] = pd.to_numeric(df['fatalities'], errors='coerce').fillna(0)
df['fatalities_clipped'] = df['fatalities'].clip(upper=50)
df['desc_length'] = df['clean_description'].apply(lambda x: len(x.split()))
df['inter1'] = pd.to_numeric(df['inter1'], errors='coerce').fillna(0).astype(int)
df['interaction'] = pd.to_numeric(df['interaction'], errors='coerce').fillna(0).astype(int)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\envs\acled\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'inter1'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 5
#       3 df['fatalities_clipped'] = df['fatalities'].clip(upper=50)
#       4 df['desc_length'] = df['clean_description'].apply(lambda x: len(x.split()))
# ----> 5 df['inter1'] = pd.to_numeric(df['inter1'], errors='coerce').fillna(0).astype(int)
#       6 df['interaction'] = pd.to_numeric(df['interaction'], errors='coerce').fillna(0).astype(int)
#
# File ~\anaconda3\envs\acled\lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File ~\anaconda3\envs\acled\lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3807     if isinstance(casted_key, slice) or (
#    3808         isinstance(casted_key, abc.Iterable)
#    3809         and any(isinstance(x, slice) for x in casted_key)
#    3810     ):
#    3811         raise InvalidIndexError(key)
# -> 3812     raise KeyError(key) from err
#    3813 except TypeError:
#    3814     # If we have a listlike key, _check_indexing_error will raise
#    3815     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3816     #  the TypeError.
#    3817     self._check_indexing_error(key)
#
# KeyError: 'inter1'

# %%
# One-hot encode categorical structured features
df = pd.get_dummies(df, columns=['inter1', 'interaction'], prefix=['actor_type', 'interaction'], drop_first=True)

# Text vectorization (TF-IDF)
vectorizer = TfidfVectorizer(max_features=5000)
X_text = vectorizer.fit_transform(df['clean_description'])

# Combine text features with structured ones

structured_features = df[['fatalities_clipped', 'desc_length'] + 
    [col for col in df.columns if col.startswith('actor_type_') or col.startswith('interaction_')]
]

X_structured = structured_features.reset_index(drop=True)

# %%
# Combine sparse matrix with dense DataFrame
from scipy.sparse import hstack
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_structured_scaled = scaler.fit_transform(X_structured)
X_combined = hstack([X_text, X_structured_scaled])

# Target variable
y = df['event_type']

# Train/test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_combined, y, test_size=0.2, stratify=y, random_state=42)

# %%
# Train logistic regression
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train, y_train)

# %%
# Evaluate
y_pred = clf.predict(X_test)

# %%
print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, target_names=y.cat.categories))

# Normalized confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=y.cat.categories, normalize='true')
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=y.cat.categories,
            yticklabels=y.cat.categories)
plt.title("Normalized Confusion Matrix - Logistic Regression (Text + Structured Features)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()
