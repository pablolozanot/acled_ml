# %% [markdown]
# # 04_model_clean_text.ipynb
#
# This notebook trains a baseline logistic regression model using only the cleaned event description stored in "clean_description" (lemmatized) from the ACLED dataset.

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 1. Load preprocessed dataset (with clean_description)
df = pd.read_pickle("acled_cleaned.pkl")

# %%
# 2. Filter to necessary columns
X_text = df['clean_description']
y = df['event_type']

# %%
# 3. Train-test split
X_train, X_test, y_train, y_test = train_test_split(
    X_text, y, test_size=0.2, stratify=y, random_state=42
)

# %%
# 4. TF-IDF vectorization
vectorizer = TfidfVectorizer(max_features=5000)
X_train_tfidf = vectorizer.fit_transform(X_train)
X_test_tfidf = vectorizer.transform(X_test)

# %%
# 5. Train logistic regression model
clf = LogisticRegression(max_iter=1000)
clf.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
# 6. Predict and evaluate
y_pred = clf.predict(X_test_tfidf)

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred, target_names=y.cat.categories))
# Out:
# Classification Report:
#
#                             precision    recall  f1-score   support
#
#                    Battles       0.94      0.93      0.93       577
# Explosions/Remote violence       0.98      0.98      0.98      1068
#                   Protests       0.97      1.00      0.98      1487
#                      Riots       0.91      0.69      0.79       169
#     Strategic developments       0.95      0.92      0.93       327
# Violence against civilians       0.87      0.90      0.89       372
#
#                   accuracy                           0.96      4000
#                  macro avg       0.94      0.90      0.92      4000
#               weighted avg       0.95      0.96      0.95      4000

# %%
# 7. Confusion Matrix


# Generate normalized confusion matrix
cm = confusion_matrix(y_test, y_pred, labels=y.cat.categories, normalize='true')

# Plot with seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='.2f', cmap='Blues',
            xticklabels=y.cat.categories,
            yticklabels=y.cat.categories)

plt.title("Normalized Confusion Matrix - Logistic Regression (Cleaned Text)")
plt.xlabel("Predicted")
plt.ylabel("True")
plt.tight_layout()
plt.show()
# Optional interpretation hint
# A confusion matrix shows where the model confuses one class with another.
# Ideal model has strong diagonal (correct predictions) and few off-diagonal elements.

# %% [markdown]
# ### Model Evaluation: Cleaned Text vs Raw Text (Same Dataset, Logistic Regression)
#
# | **Metric**                    | **Before (Raw Text)** | **After (Cleaned Text)** | **What It Means**                                                                                                                                 |
# |-------------------------------|------------------------|---------------------------|----------------------------------------------------------------------------------------------------------------------------------------------------|
# | **Accuracy**                  | 0.94                   | **0.96**                  | **Overall correctness** — proportion of total predictions that were correct across all classes.                                                 |
# | **Macro F1-score**            | 0.90                   | **0.92**                  | **Balanced performance across all classes**, regardless of size. This averages the F1-score *per class* equally.                                |
# | **Weighted F1-score**         | 0.94                   | **0.95**                  | **Overall performance weighted by class size** — better reflects performance on dominant classes, like "Protests".                              |
# | **Recall (Riots)**            | 0.67                   | **0.69**                  | **Of all real Riots, how many were correctly predicted**? Low recall means the model is missing some real riot events.                         |
# | **Recall (Strategic Dev.)**   | 0.82                   | **0.92**                  | **True positive rate for Strategic Developments** — big improvement indicates cleaner descriptions helped distinguish this nuanced category.   |
