# %% [markdown]
# # 03 – Text Cleaning & Feature Enrichment
#
# In this notebook, we:
#  - Preprocess event descriptions to reduce noise
#  - Add structured features (e.g. country, fatalities)
#  - Prepare input for modeling

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk
from nltk.corpus import stopwords
from tqdm import tqdm
import spacy
import string

# %%
# Load data
df = pd.read_csv("acled_sample.csv")  # or re-query BigQuery
#df = df[['event_description', 'event_type', 'fatalities', 'country', 'actor1']].dropna()

# Make sure target is categorical
df['event_type'] = df['event_type'].astype('category')
df['label'] = df['event_type'].cat.codes

# %%
df.head()
# Out:
#    Unnamed: 0 event_id_cnty                  event_type  event_date  \
# 0           0      SOM45530  Explosions/Remote violence  2024-08-25
# 1           1      SOM45523  Violence against civilians  2024-08-24
# 2           2        MUS523                    Protests  2024-08-27
# 3           3     IND165800      Strategic developments  2024-08-27
# 4           4      IRQ58463      Strategic developments  2024-08-27
#
#      country   admin1    admin2                  actor1  \
# 0    Somalia  Banadir   Banadir              Al Shabaab
# 1    Somalia  Banadir   Banadir              Al Shabaab
# 2  Mauritius     Moka       NaN  Protesters (Mauritius)
# 3      India    Assam    Nagaon       Civilians (India)
# 4       Iraq   Ninewa  Al Mosul        Civilians (Iraq)
#
#                                               actor2      inter1  \
# 0                 Military Forces of Somalia (2022-)         NaN
# 1                                Civilians (Somalia)         NaN
# 2  Police Forces of Mauritius (2018-) Special Sup...  Protesters
# 3                                                NaN   Civilians
# 4                                                NaN   Civilians
#
#       interaction                                  event_description  \
# 0             NaN  On 25 August 2024, an IED planted by Al Shabaa...
# 1             NaN  On 24 August 2024, Al Shabaab shot and killed ...
# 2             NaN  On 27 August 2024, at the call of the Rann Nou...
# 3  Civilians only  Other: On 27 August 2024, a section of fish tr...
# 4  Civilians only  Other: On 27 August 2024, 517 displaced people...
#
#    fatalities  latitude  longitude  label
# 0           2    2.0611    45.2589      1
# 1           2    2.0576    45.2853      5
# 2           0  -20.2190    57.5108      2
# 3           0   26.3469    92.6851      4
# 4           0   36.3350    43.1189      4

# %%
nlp = spacy.load("en_core_web_sm")

def clean_and_lemmatize_pipe(docs):
    cleaned = []
    for doc in tqdm(nlp.pipe(docs, batch_size=1000, n_process=1), total=len(docs)):
        tokens = [token.lemma_ for token in doc if not token.is_stop and token.lemma_.isalpha()]
        cleaned.append(" ".join(tokens))
    return cleaned

# progress bar
df['clean_description'] = clean_and_lemmatize_pipe(df['event_description'].fillna(""))
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████| 20000/20000 [02:51<00:00, 116.72it/s]

# %%
df[['event_description', 'clean_description']].head()
# Out:
#                                    event_description  \
# 0  On 25 August 2024, an IED planted by Al Shabaa...
# 1  On 24 August 2024, Al Shabaab shot and killed ...
# 2  On 27 August 2024, at the call of the Rann Nou...
# 3  Other: On 27 August 2024, a section of fish tr...
# 4  Other: On 27 August 2024, 517 displaced people...
#
#                                    clean_description
# 0  August ied plant Al Shabaab detonate target go...
# 1  August Al Shabaab shoot kill government soldie...
# 2  August Rann Nou La Terre movement Indo Mauriti...
# 3  August section fish trader announce halt expor...
# 4  August displace people return Dibaga Camp Erbi...

# %% [markdown]
# ## Feature extraction
#
# Fatalities, description length, actor type

# %%
# Ensure these are numeric
df['fatalities'] = pd.to_numeric(df['fatalities'], errors='coerce').fillna(0)
df['fatalities_clipped'] = df['fatalities'].clip(upper=50)

# Description length
df['desc_length'] = df['clean_description'].apply(lambda x: len(x.split()))

# Interactions
df['inter1'] = pd.to_numeric(df['inter1'], errors='coerce').fillna(0).astype(int)
df['interaction'] = pd.to_numeric(df['interaction'], errors='coerce').fillna(0).astype(int)

# One-hot encode both
df = pd.get_dummies(df, columns=['inter1', 'interaction'], drop_first=True)

# %%
df.to_pickle("acled_cleaned.pkl")
